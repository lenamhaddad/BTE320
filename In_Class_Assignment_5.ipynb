# %% [markdown]
# <a href="https://colab.research.google.com/github/lenamhaddad/BTE320/blob/main/In_Class_Assignment_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rock Paper Scissors

# %%
import random

play = input("Do you want to play (yes/no)?: ")
while play == "yes":
  user_move = input("Enter rock, paper, or scissors: ")
  computer_move = random.choice(['rock','paper','scissors'])
  print(f"Computer chose: {computer_move}")

  print(f"Player move: {p_move}\nComputer move: {c_move}")

  if user_move == computer_move:
    print("Tie")
  elif (user_move == "rock" and computer_move == "scissors") or (user_move == "paper" and computer_move == "rock") or (user_move == "scissors" and computer_move == "paper"):
    print("Win")
  elif (user_move == "rock" and computer_move == "paper") or  (user_move == "paper" and computer_move == "scissors") or (user_move == "scissors" and computer_move == "rock"):
    print("Lose")

# %%
import random

play = input("Do you want to play (y/n): ").lower()

while play == "y":
  p_move = input("Choose between rock, paper, scissors: ").lower()
  c_move = random.choice(['rock','paper','scissors'])

  print(f"Player move: {p_move}\nComputer move: {c_move}")

  if p_move == c_move:
    print("Draw")
  elif (
        (p_move == "rock" and c_move == "scissors") or
        (p_move == "scissors" and c_move == "paper") or
        (p_move == "paper" and c_move == "rock")
        ):
    print("Player Wins")
  else:
    print("Computer Wins")

  play = input("Do you want to play again (y/n): ")
# Out:
# Do you want to play (y/n): n
