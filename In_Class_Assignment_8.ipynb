# %% [markdown]
# <a href="https://colab.research.google.com/github/lenamhaddad/BTE320/blob/main/In_Class_Assignment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names = {}

while True:
  name = input("Give a name: ")
  if name == "":
    break

  if name in names:
    names[name] += 1
  else:
    names[name] = 1

print(names)
# Out:
# Give a name: bob
# Give a name: alice
# Give a name: eve
# Give a name: bib
# Give a name:
# {'bob': 1, 'alice': 1, 'eve': 1, 'bib': 1}
